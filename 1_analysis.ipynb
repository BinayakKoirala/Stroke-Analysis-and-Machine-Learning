# %% [markdown]
# <a href="https://colab.research.google.com/github/BinayakKoirala/Stoke-Analysis-and-Machine-Learning/blob/main/1_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)

# %% [markdown]
# ## **DATA DESCRIPTION**

# %%
data=pd.read_csv('brain_stroke.csv')
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
data.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
data.shape
# Out:
# (4981, 11)

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
data.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
data.isnull().sum() #checking for total null values
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# In this data set, there are no any NULL values.
#
# ---

# %% [markdown]
# **If we see any feature unrelated to label, we can just drop them before starting to Exploratory Data Analysis**
#
# > Indented block

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %% [markdown]
# ## HOW MANY PEOPLE HAD STROKE BEFORE ??

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['stroke'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('had stroke')
ax[0].set_ylabel('')
sns.countplot('stroke',data=data,ax=ax[1])
ax[1].set_title('had stroke')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# This is an imbalanced dataset since the number of patients that are likely to get a stroke is smaller when compared with the number of patients that did not.

# %% [markdown]
# ##CATEGORICAL FEATURE : GENDER

# %%
data.groupby(['gender','stroke'])['stroke'].count()
# Out:
# gender  stroke
# Female  0         2767
#         1          140
# Male    0         1966
#         1          108
# Name: stroke, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(10,7))
data[['gender','stroke']].groupby(['gender']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Had a stroke vs Gender')
sns.countplot('gender',hue='stroke',data=data,ax=ax[1])
ax[1].set_title('Gender:Had a Stroke vs Not had a Stroke')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Observation:**
# -The number of female gender is more than male gender for both cases.
# -The Gender variable by itself is not enough to predict the likely hood of getting a stroke.

# %% [markdown]
# ##CATEGORICAL FEATURE : HEART DISEASE

# %%
data.groupby(['heart_disease','stroke'])['stroke'].count()
# Out:
# heart_disease  stroke
# 0              0         4505
#                1          201
# 1              0          228
#                1           47
# Name: stroke, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(10,7))
data[['heart_disease','stroke']].groupby(['heart_disease']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Had a stroke and heart_disease')
sns.countplot('heart_disease',hue='stroke',data=data,ax=ax[1])
ax[1].set_title('heart_disease:Had a Stroke but Not had a Stroke')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Observation:
# 1.

# %% [markdown]
# ##CATEGORICAL FEATURE: HYPERTENSION

# %%
data.groupby(['hypertension','stroke'])['stroke'].count()
# Out:
# hypertension  stroke
# 0             0         4320
#               1          182
# 1             0          413
#               1           66
# Name: stroke, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(10,7))
data[['hypertension','stroke']].groupby(['hypertension']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Had a stroke vs Having hypertesion')
sns.countplot('hypertension',hue='stroke',data=data,ax=ax[1])
ax[1].set_title('hypertension:Had a Stroke vs Not had a Stroke')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# So if we look at the visualization, in case of having hypertension or not, a very similar rate of stroke appears.

# %% [markdown]
# ## PIE CHARTS

# %%
fig, ax = plt.subplots(4,2, figsize = (14,14))
((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = ax

labels = data['gender'].value_counts().index.tolist()[:2]
values = data['gender'].value_counts().tolist()[:2]
ax1.pie(x=values, labels=labels, autopct="%1.1f%%",colors=['#FF9933','#19FF66'],shadow=True, startangle=45,explode=[0.01, 0.1])
ax1.set_title("Gender", fontdict={'fontsize': 12},fontweight ='bold')

labels = ["No Hypertension", "Hypertension"]
values = data['hypertension'].value_counts().tolist()
ax2.pie(x=values, labels=labels, autopct="%1.1f%%",colors=['#FF9933','#19FF66'],shadow=True,startangle=45,explode=[0.1, 0.15])
ax2.set_title("Hypertension", fontdict={'fontsize': 12},fontweight ='bold')

labels = ["No Heart Disease", "Heart Disease"]
values = data['heart_disease'].value_counts().tolist()
ax3.pie(x=values, labels=labels, autopct="%1.1f%%",colors=['#AA80FF','#FF9933'],shadow=True, startangle=45,explode=[0.1, 0.15])
ax3.set_title("Heart disease", fontdict={'fontsize': 12},fontweight ='bold')

labels = ["Married", "Not Married"]
values = data['ever_married'].value_counts().tolist()
ax4.pie(x=values, labels=labels, autopct="%1.1f%%", colors=['#FF9933','#AA80FF'],shadow=True,startangle=45,explode=[0, 0.05])
ax4.set_title("Marriage", fontdict={'fontsize': 12},fontweight ='bold')

labels = ["Private", "Self-employed", "children", "Govt_job"]
values = data['work_type'].value_counts().tolist()
ax5.pie(x=values, labels=labels, autopct="%1.1f%%", colors=['#66b3ff','#FF9933','#19FF66','#FF6699'],shadow=True, startangle=45,explode=[0.1, 0.1, 0.1, 0.1])
ax5.set_title("Work Type", fontdict={'fontsize': 12},fontweight ='bold')

labels = ["Urban", "Rural"]
values = data['Residence_type'].value_counts().tolist()
ax6.pie(x=values, labels=labels, autopct="%1.1f%%", colors=['#66b3ff','#19FF66'],shadow=True,startangle=45,explode=[0.05, 0.05])
ax6.set_title("Residence Type", fontdict={'fontsize': 12},fontweight ='bold')

labels = ["Never Smoked", "Unknown", "Smoked", "Smokes"]
values = data['smoking_status'].value_counts().tolist()
ax7.pie(x=values, labels=labels, autopct="%1.1f%%", shadow=True, startangle=45,explode=[0.05, 0.07, 0.1, 0.1],colors=['#AA80FF','#66b3ff','#19FF66','#FF6699'])
ax7.set_title("Smoking Status", fontdict={'fontsize': 12},fontweight ='bold')

labels = ["No Stroke", "Stroke"]
values = data['stroke'].value_counts().tolist()
ax8.pie(x=values, labels=labels, autopct="%1.1f%%", shadow=True, startangle=45,explode=[0.01, 0.3],colors=['#19FF66','#FF9933'])
ax8.set_title("Stroke", fontdict={'fontsize': 12},fontweight ='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##COUNT  PLOTS

# %%
fig,axes = plt.subplots(4,2,figsize = (15,15))
fig.suptitle("Count plot for categorical features")
#gender
sns.countplot(ax=axes[0,0],data=data,x='gender')
#smoking_status
sns.countplot(ax=axes[0,1],data=data,x='smoking_status')
#heart_disease
sns.countplot(ax=axes[1,0],data=data,x='heart_disease')
#ever_married
sns.countplot(ax=axes[1,1],data=data,x='ever_married')
#work_type
sns.countplot(ax=axes[2,0],data=data,x='work_type')
#Residence_type
sns.countplot(ax=axes[2,1],data=data,x='Residence_type')
#hypertension
sns.countplot(ax=axes[3,0],data=data,x='hypertension')
#stroke
sns.countplot(ax=axes[3,1],data=data,x='stroke')
plt.show()

# %%
fig, axes = plt.subplots(3,2, figsize=(15,12),sharey=True)
sns.countplot(x = 'gender',hue = 'stroke',data = data, ax = axes[0,0])
sns.countplot(x = 'heart_disease',hue = 'stroke',data = data, ax = axes[0,1])
sns.countplot(x = 'ever_married',hue = 'stroke', data = data, ax = axes[1,0])
sns.countplot(x = 'Residence_type', hue = 'stroke', data = data, ax = axes[2,0])
sns.countplot(x = data['smoking_status'], ax = axes[2,1])
sns.countplot(x = data['work_type'], ax = axes[1,1])

# %% [markdown]
# ## CORRELATION

# %%
f,ax = plt.subplots(figsize=(12, 12))
ax.set_title('Correlation map for variables')
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax,cmap="icefire")

# %% [markdown]
# ## Stroke-Cases Analysis

# %%
data[data["stroke"]==1].describe()
# Out:
#               age  hypertension  heart_disease  avg_glucose_level         bmi  \
# count  248.000000    248.000000     248.000000         248.000000  248.000000
# mean    67.819839      0.266129       0.189516         132.175565   30.186694
# std     12.670565      0.442826       0.392711          61.771083    5.658245
# min      1.320000      0.000000       0.000000          56.110000   16.900000
# 25%     59.000000      0.000000       0.000000          79.572500   26.975000
# 50%     71.000000      0.000000       0.000000         105.040000   29.450000
# 75%     78.000000      1.000000       0.000000         195.960000   32.650000
# max     82.000000      1.000000       1.000000         271.740000   48.900000
#
#        stroke
# count   248.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0

# %% [markdown]
# INSIGHTS :
# 1. People having age greater than 67 are more likely to suffer from stroke.
# 2. People having avg glucose level greater than 132 are prone to stroke.
# 3. People having bmi greater than 30 are prone to stroke.

# %% [markdown]
# ##STROKE AND AGE

# %%
sns.FacetGrid(data, hue="stroke", height = 8).map(sns.distplot, "age").add_legend()
plt.title("Distplot for patients' age")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Insight**: Higher the age, higher the chances of getting stroke.

# %% [markdown]
# ##STROKE AND GENDER

# %%
data["gender"].value_counts().plot(kind="bar")
plt.title("distribution of gender")
# Out:
# Text(0.5, 1.0, 'distribution of gender')

# %%
sns.violinplot(x="gender",y="stroke",data=data)

# %% [markdown]
# Violin plot is used for visualising probability distribution.

# %%
data.groupby("gender").stroke.mean()
# Out:
# gender
# Female    0.048160
# Male      0.052073
# Name: stroke, dtype: float64

# %% [markdown]
# **INSIGHT**
# - According to this dataset, Male has 5.2% chances of having stroke and women have 4.8% chance of having stroke.

# %% [markdown]
# ##STROKE AND HYPERTENSION

# %%
data["hypertension"].value_counts().plot(kind= "bar")

# %%
sns.catplot(x="hypertension",hue="stroke",kind="count",data=data)

# %%
data.groupby("hypertension").stroke.mean()
# Out:
# hypertension
# 0    0.040426
# 1    0.137787
# Name: stroke, dtype: float64

# %% [markdown]
# **INSIGHT** :
# - Acoording to the above analysis, 13.77% people having hypertension have stroke and 4.04% people not having hypertension suffer from stroke.

# %% [markdown]
# ##STROKE AND HEART DISEASE

# %%
sns.catplot(x="hypertension",hue="stroke",kind="count",data=data)

# %%
data.groupby("heart_disease").stroke.mean()
# Out:
# heart_disease
# 0    0.042711
# 1    0.170909
# Name: stroke, dtype: float64

# %% [markdown]
# INSIGHT :
# - According to the above analysis, People having heart disease tend to have stroke by 17.09% and people having no heart disease have a 4.27% of having a stroke.

# %% [markdown]
# ##STROKE AND AVERAGE GLUCOSE LEVEL

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data["avg_glucose_level"],shade=True)
plt.xlabel("avg_glucose_level")
plt.ylabel("Density")
plt.title("Distribution of Avg glucose level")
# Out:
# Text(0.5, 1.0, 'Distribution of Avg glucose level')

# %% [markdown]
# INSIGHT:
# - People having avg glucose level less than 140 are more likely to suffer from stroke.

# %% [markdown]
# ## STROKE AND BMI

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data["bmi"],shade=True)
plt.xlabel("bmi")
plt.ylabel("Density")
plt.title("Distribution of BMI")
# Out:
# Text(0.5, 1.0, 'Distribution of BMI')

# %% [markdown]
# INSIGHT:
# - People having bmi between 20 and 35 have more chances of stroke.

# %% [markdown]
# ## STROKE AND SMOKING STATUS

# %%
data["smoking_status"].value_counts().plot(kind="bar")
plt.title("distribution of gender")
# Out:
# Text(0.5, 1.0, 'distribution of gender')

# %%
data.groupby("smoking_status").stroke.mean()
# Out:
# smoking_status
# Unknown            0.031333
# formerly smoked    0.080738
# never smoked       0.048422
# smokes             0.054124
# Name: stroke, dtype: float64

# %% [markdown]
# **INSIGHTS**
# - 8.0% of people who previously smoked has a chance of getting stroke.
# - 4.8% of people who never smoked has a chance of getting stroke.
# - 5.4% of people who smokes has a chance of getting stroke.
# - 3.1% of people who are unknown about thier smoking status has a chance of getting stroke.

# %% [markdown]
# ##STROKE AND MARRIED STATUS

# %%
data["ever_married"].value_counts().plot(kind="bar")
plt.title("distribution of gender")
# Out:
# Text(0.5, 1.0, 'distribution of gender')

# %%
data.groupby("ever_married").stroke.mean()
# Out:
# ever_married
# No     0.017049
# Yes    0.066768
# Name: stroke, dtype: float64

# %% [markdown]
# **INSIGHTS**:
# - Only 1.7% of unmarried people has chance of getting stroke.
# - 6.6% of married people has chance of getting stroke.

# %% [markdown]
# ##STROKE AND WORK TYPE

# %%
data["work_type"].value_counts().plot(kind="bar")
plt.title("distribution of gender")
# Out:
# Text(0.5, 1.0, 'distribution of gender')

# %%
data.groupby("work_type").stroke.mean()
# Out:
# work_type
# Govt_job         0.051242
# Private          0.051748
# Self-employed    0.080846
# children         0.002972
# Name: stroke, dtype: float64

# %% [markdown]
# **INSIGHTS**
# - Among people having government job, 5.124% has chance of getting stroke.
# - Among people having private job, 5.174% has chance of getting stroke.
# - Among people who are self employed, 8.08% has chance of getting stroke.
# - Only 0.2% of children has chance of getting stroke.

# %% [markdown]
# ##STROKE AND RESIDENCE TYPE

# %%
data["Residence_type"].value_counts().plot(kind="bar")
plt.title("distribution of gender")
# Out:
# Text(0.5, 1.0, 'distribution of gender')

# %%
data.groupby("Residence_type").stroke.mean()
# Out:
# Residence_type
# Rural    0.046141
# Urban    0.053318
# Name: stroke, dtype: float64

# %% [markdown]
# **INSIGHTS**
# - 4.6% of people living in rural area has chance of getting stroke.
# - 5.3% of people living in urban area has chance of getting stroke.
